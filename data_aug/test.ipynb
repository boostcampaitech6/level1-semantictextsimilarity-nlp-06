# %%
import json

with open('data_eunhy.json', 'r', encoding = 'utf-8-sig') as f:
    dict1 = json.load(f)

with open('data_insoo.json', 'r', encoding = 'utf-8-sig') as f:
    dict2 = json.load(f)

with open('data_kunha.json', 'r', encoding = 'utf-8-sig') as f:
    dict3 = json.load(f)

with open('data_jaeha.json', 'r', encoding = 'utf-8-sig') as f:
    dict4 = json.load(f)

# %%
print(dict1)
print(dict2)
print(dict3)
print(dict4)
# Out:
# {'기억': ['강기', '각인', '간직'], '대책': ['대처', '대안', '대비책', '방책', '대응책'], '글': ['글씨', '글쓰기', '한글', '글발', '글자', '언문'], '제안': ['제시', '안', '발의', '건의'], '개정': ['수정', '경정', '변경'], '요구': ['청구', '필요', '요청', '간구', '구청', '부탁'], '소년법': ['형법'], '진행': ['전개', '발전', '추진'], '인생': ['생애', '삶', '생'], '말씀': ['설교', '얘기', '고화', '예비미사', '금구', '고담', '이야기'], '건강': ['강녕', '건승'], '먼지': ['미진', '진개', '티끌', '분진', '설진'], '지금': ['현재', '금시', '당장'], '현실': ['현재', '사실', '실상', '실제'], '해결': ['낙착', '수습', '정리'], '임금': ['급료', '임금님', '국왕', '군부', '군왕', '임금', '대가', '보수'], '돈': ['돈뭉치', '돈다발', '금전', '지폐'], '영상': ['영상물', '광경', '모습', '비디오'], '미세': ['초미세', '미말'], '학교': ['공고', '소학', '고등학교', '소학교', '고교', '배움터'], '환영': ['허깨비', '허상', '환형', '환상'], '올림픽': ['국제올림픽경기대회', '오륜대회'], '오피스': ['사무실'], '액션': ['연기', '동작'], '서울': ['서울특별시', '경성'], '인상': ['골상', '관상', '면목'], '판사': ['재판관', '법관'], '장면': ['광경'], '불법': ['편법', '위법', '비합법', '비법'], '기분': ['기의', '느낌', '감정'], '최저': ['최소', '최하'], '부분': ['부위', '부문', '일부분', '갈래', '계통', '구석'], '보호': ['보수', '보장', '그늘', '
# ...

# %%
updated_top_200 = dict()

updated_top_200.update(dict1)
updated_top_200.update(dict2)
updated_top_200.update(dict3)
updated_top_200.update(dict4)
# Out:
# 198

# %%
with open('combined.json', 'w', encoding='utf-8-sig') as file:
    json.dump(combined_dict, file, ensure_ascii=False)

# %%
with open('combined.json', 'r'):
    pass
